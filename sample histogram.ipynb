# %%
# %matplotlib inline
import numpy, scipy, matplotlib.pyplot as plt, IPython.display as ipd
import librosa, librosa.display
import numpy as np
x, sr = librosa.load('/Users/tanchonghong/Documents/1_2020_s2/assignment/violin/violin_C4_1_forte_arco-normal.mp3')
hop_length = 512
X = librosa.stft(x)
S = librosa.amplitude_to_db(X, ref=np.max)  
#normalization by setting the sample sound with largest amplitude(dB) as 0dB and put

# %% [markdown]
# '''
# X = librosa.stft(x)
# S = librosa.amplitude_to_db(abs(X))
# '''
# Each row of S represent a frequency bin while each column of S represents the sample no(time)

# %%
import math

l1 =[]
#by default, there are 1025 frequency bins in 0 to sr/2 (sr = 22050)

l2 = [0]*(int(len(S)*((22050/2)/1025))) #convert normalized frequency to ground truth frequency
hist=[]
for i in range(len(S)):
    for j in range(len(S[0])):
        
        if S[i][j]>=(-10):
            temp = i *((22050/2)/1025)
            
            #print(temp)
            hist.append(math.log2(temp))
            l2[int(temp)]+=1

for i in range(1,len(l2)+1):
    l1.append(i)

# %%
plt. clf()
plt.figure(figsize=(15,10))
plt.subplot(311)
plt.title('Occurence against frequency')
plt.xlabel('Frequency (2 ^ i)')
plt.ylabel('Occurence')
plt.hist(hist)
plt.subplot(313)
plt.title('Occurence against frequency')
plt.xlabel('Frequency (hertz)')
plt.ylabel('Occurence')
plt.plot(l1,l2)

# %%
mfccs = librosa.feature.mfcc(x, sr=sr)
print(mfccs.shape)
#Displaying  the MFCCs:
librosa.display.specshow(mfccs, sr=sr, x_axis='time')

# %%
# %matplotlib inline
import numpy, scipy, matplotlib.pyplot as plt, IPython.display as ipd
import librosa, librosa.display
import numpy as np
x, sr = librosa.load('/Users/tanchonghong/Documents/1_2020_s2/assignment/oboe/oboe_C4_1_forte_normal.mp3')
hop_length = 512
X = librosa.stft(x)
S = librosa.amplitude_to_db(X, ref=np.max)  
#normalization by setting the sample sound with largest amplitude(dB) as 0dB and put
plt.figure(figsize=(15, 5))
librosa.display.specshow(S, sr=sr, hop_length=hop_length, x_axis='time', y_axis='log')
plt.colorbar(format='%+2.0f dB')

# %%
mfccs = librosa.feature.mfcc(x, sr=sr)
print(mfccs.shape)
#Displaying  the MFCCs:
librosa.display.specshow(mfccs, sr=sr, x_axis='time')

# %%
import os
import librosa, librosa.display
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math
import statistics
os.chdir('/home/student/Downloads/new_violin_viola/baroque/violin/solo/')
f_name = "/home/student/Downloads/new_violin_viola/baroque/violin/solo/Fantasia in F major.mp3"
y, sr = librosa.load(f_name)
#mel = librosa.feature.melspectrogram(y=y,sr=sr)
X = librosa.stft(y)
S = librosa.amplitude_to_db(X, ref=np.max)
plt. clf()
fig = plt.figure(figsize=(12.0, 8.0)) #for full size graph download
librosa.display.specshow(S, y_axis='mel')
plt.colorbar(format='%+2.0f dB')
#plt.savefig(f'/home/student/Downloads/new_violin_viola/baroque/violin/solo/Hilary Hahn - J.S. Bach Partita for Violin Solo No. 1 in B Minor, BWV 1002 - 4. Doubl....mp3.png')
hop_length = 512
X = librosa.stft(y)
S = librosa.amplitude_to_db(X, ref=np.max)
        
l1 =[]
        #by default, there are 1025 frequency bins in 0 to sr/2 (sr = 22050)

        
hist=[]
hist1=[]
for i in range(len(S)):
    for j in range(len(S[0])):
        
        if S[i][j]>=(-11):
            temp = i *((22050/2)/1025)
            
            if temp >0:
                hist.append(math.log2(temp))
                hist1.append(temp)
                        

plt. clf()
fig = plt.figure(figsize=(12.0, 8.0)) #for full size graph download

plt.xticks(size = 30)
plt.yticks(size = 30)
plt.xlabel('Base 2 Logarithm of Frequency (Hz)', fontsize=25,fontweight='bold')
plt.ylabel('Occurrence', fontsize=25,fontweight='bold')
plt.hist(hist)

os.chdir('/home/student/Downloads')
plt.savefig('hist11.eps', format='eps')
a = hist
temp =[statistics.mean(a), statistics.median(a), statistics.mode(a), min(a), max(a),np.percentile(np.array(a), 25), np.percentile(np.array(a), 75)]
print(temp)
# Out:
# /home/student/.local/lib/python3.6/site-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/student/.local/lib/python3.6/site-packages/librosa/core/spectrum.py:1642: UserWarning: amplitude_to_db was called on complex input so phase information will be discarded. To suppress this warning, call amplitude_to_db(np.abs(S)) instead.
#   "amplitude_to_db was called on complex input so phase "
# [9.039761128260205, 8.918935937269111, 8.95064479699645, 8.070939030714161, 11.679748273389686, 8.784634845557521, 9.041792685054645]

# %%
#os.chdir('/home/student/Downloads/new_violin_viola/baroque/viola/solo/')
f_name = "/home/student/Downloads/new_violin_viola/baroque/viola/solo_train/Suite No.5 in C minor, BWV 1011 I. Prélude.mp3"
y, sr = librosa.load(f_name)
#mel = librosa.feature.melspectrogram(y=y,sr=sr)
X = librosa.stft(y)
S = librosa.amplitude_to_db(X, ref=np.max)
plt. clf()
fig = plt.figure(figsize=(12.0, 8.0)) #for full size graph download
librosa.display.specshow(S, y_axis='mel')
plt.colorbar(format='%+2.0f dB')
#plt.savefig(f'/home/student/Downloads/new_violin_viola/baroque/violin/solo/Hilary Hahn - J.S. Bach Partita for Violin Solo No. 1 in B Minor, BWV 1002 - 4. Doubl....mp3.png')
hop_length = 512
X = librosa.stft(y)
S = librosa.amplitude_to_db(X, ref=np.max)
        
l1 =[]
        #by default, there are 1025 frequency bins in 0 to sr/2 (sr = 22050)

        
hist=[]
hist1=[]
for i in range(len(S)):
    for j in range(len(S[0])):
        
        if S[i][j]>=(-11):
            temp = i *((22050/2)/1025)
            
            if temp >0:
                hist.append(math.log2(temp))
                hist1.append(temp)
                        

plt. clf()
fig = plt.figure(figsize=(12.0, 8.0)) #for full size graph download
plt.xticks(size = 30)
plt.yticks(size = 30)
plt.xlabel('Base 2 Logarithm of Frequency (Hz)', fontsize=25,fontweight='bold')
plt.ylabel('Occurrence', fontsize=25,fontweight='bold')
plt.hist(hist)
os.chdir('/home/student/Downloads')
plt.savefig('hist12.eps', format='eps')
plt.savefig('hist12.png', format='png')
a = hist
temp =[statistics.mean(a), statistics.median(a), statistics.mode(a), min(a), max(a),np.percentile(np.array(a), 25), np.percentile(np.array(a), 75)]
print(temp)
# Out:
# /home/student/.local/lib/python3.6/site-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/student/.local/lib/python3.6/site-packages/librosa/core/spectrum.py:1642: UserWarning: amplitude_to_db was called on complex input so phase information will be discarded. To suppress this warning, call amplitude_to_db(np.abs(S)) instead.
#   "amplitude_to_db was called on complex input so phase "
# [8.55657440328343, 8.47147696029789, 8.47147696029789, 7.95064479699645, 10.703207246213674, 8.427082840939438, 8.712485059801685]

# %%
os.chdir('/home/student/Downloads/new_violin_viola/classical/violin/solo_test')
f_name = "/home/student/Downloads/new_violin_viola/classical/violin/solo_test/Ave María, F. Schubert (Violín solo).mp3"
y, sr = librosa.load(f_name)
#mel = librosa.feature.melspectrogram(y=y,sr=sr)
X = librosa.stft(y)
S = librosa.amplitude_to_db(X, ref=np.max)
plt. clf()
fig = plt.figure(figsize=(12.0, 8.0)) #for full size graph download
librosa.display.specshow(S, y_axis='mel')
plt.colorbar(format='%+2.0f dB')
#plt.savefig(f'/home/student/Downloads/new_violin_viola/baroque/violin/solo/Hilary Hahn - J.S. Bach Partita for Violin Solo No. 1 in B Minor, BWV 1002 - 4. Doubl....mp3.png')
hop_length = 512
X = librosa.stft(y)
S = librosa.amplitude_to_db(X, ref=np.max)
        
l1 =[]
        #by default, there are 1025 frequency bins in 0 to sr/2 (sr = 22050)

        
hist=[]
hist1=[]
for i in range(len(S)):
    for j in range(len(S[0])):
        
        if S[i][j]>=(-11):
            temp = i *((22050/2)/1025)
            
            if temp >0:
                hist.append(math.log2(temp))
                hist1.append(temp)
                        

plt. clf()
fig = plt.figure(figsize=(12.0, 8.0)) #for full size graph download
plt.xticks(size = 30)
plt.yticks(size = 30)
plt.xlabel('Base 2 Logarithm of Frequency (Hz)', fontsize=25,fontweight='bold')
plt.ylabel('Occurrence', fontsize=25,fontweight='bold')
plt.hist(hist,color = "cyan")
os.chdir('/home/student/Downloads')
plt.savefig('hist21.eps', format='eps')
a = hist
temp =[statistics.mean(a), statistics.median(a), statistics.mode(a), min(a), max(a),np.percentile(np.array(a), 25), np.percentile(np.array(a), 75)]
print(temp)
# Out:
# /home/student/.local/lib/python3.6/site-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/student/.local/lib/python3.6/site-packages/librosa/core/spectrum.py:1642: UserWarning: amplitude_to_db was called on complex input so phase information will be discarded. To suppress this warning, call amplitude_to_db(np.abs(S)) instead.
#   "amplitude_to_db was called on complex input so phase "
# [9.256422814061995, 9.041792685054645, 9.041792685054645, 8.59700784238175, 11.195267165716363, 9.041792685054645, 9.181970343102906]

# %%
os.chdir('/home/student/Downloads/new_violin_viola/classical/viola/solo_train')
f_name = "/home/student/Downloads/new_violin_viola/classical/viola/solo_train/Campagnoli Caprice #35 for Solo Viola.mp3"
y, sr = librosa.load(f_name)
#mel = librosa.feature.melspectrogram(y=y,sr=sr)
X = librosa.stft(y)
S = librosa.amplitude_to_db(X, ref=np.max)
plt. clf()
fig = plt.figure(figsize=(12.0, 8.0)) #for full size graph download
librosa.display.specshow(S, y_axis='mel')
plt.colorbar(format='%+2.0f dB')
#plt.savefig(f'/home/student/Downloads/new_violin_viola/baroque/violin/solo/Hilary Hahn - J.S. Bach Partita for Violin Solo No. 1 in B Minor, BWV 1002 - 4. Doubl....mp3.png')
hop_length = 512
X = librosa.stft(y)
S = librosa.amplitude_to_db(X, ref=np.max)
        
l1 =[]
        #by default, there are 1025 frequency bins in 0 to sr/2 (sr = 22050)

        
hist=[]
hist1=[]
for i in range(len(S)):
    for j in range(len(S[0])):
        
        if S[i][j]>=(-11):
            temp = i *((22050/2)/1025)
            
            if temp >0:
                hist.append(math.log2(temp))
                hist1.append(temp)
                        

plt. clf()
fig = plt.figure(figsize=(12.0, 8.0)) #for full size graph download
plt.xticks(size = 30)
plt.yticks(size = 30)
plt.xlabel('Base 2 Logarithm of Frequency (Hz)', fontsize=25,fontweight='bold')
plt.ylabel('Occurrence', fontsize=25,fontweight='bold')
plt.hist(hist,color = "cyan")
os.chdir('/home/student/Downloads')
plt.savefig('hist22.eps', format='eps')
a = hist
temp =[statistics.mean(a), statistics.median(a), statistics.mode(a), min(a), max(a),np.percentile(np.array(a), 25), np.percentile(np.array(a), 75)]
print(temp)
# Out:
# /home/student/.local/lib/python3.6/site-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/student/.local/lib/python3.6/site-packages/librosa/core/spectrum.py:1642: UserWarning: amplitude_to_db was called on complex input so phase information will be discarded. To suppress this warning, call amplitude_to_db(np.abs(S)) instead.
#   "amplitude_to_db was called on complex input so phase "
# [9.044919693043292, 8.819400263718197, 8.784634845557521, 7.819400263718197, 10.784634845557521, 8.784634845557521, 9.381279151326313]

# %%
os.chdir('/home/student/Downloads/new_violin_viola/romantic/violin/solo_train')
f_name = "/home/student/Downloads/new_violin_viola/romantic/violin/solo_train/Heinrich Wilhelm Ernst Study 3.mp3"
y, sr = librosa.load(f_name)
#mel = librosa.feature.melspectrogram(y=y,sr=sr)
X = librosa.stft(y)
S = librosa.amplitude_to_db(X, ref=np.max)
plt. clf()
fig = plt.figure(figsize=(12.0, 8.0)) #for full size graph download
librosa.display.specshow(S, y_axis='mel')
plt.colorbar(format='%+2.0f dB')
#plt.savefig(f'/home/student/Downloads/new_violin_viola/baroque/violin/solo/Hilary Hahn - J.S. Bach Partita for Violin Solo No. 1 in B Minor, BWV 1002 - 4. Doubl....mp3.png')
hop_length = 512
X = librosa.stft(y)
S = librosa.amplitude_to_db(X, ref=np.max)
        
l1 =[]
        #by default, there are 1025 frequency bins in 0 to sr/2 (sr = 22050)

        
hist=[]
hist1=[]
for i in range(len(S)):
    for j in range(len(S[0])):
        
        if S[i][j]>=(-11):
            temp = i *((22050/2)/1025)
            
            if temp >0:
                hist.append(math.log2(temp))
                hist1.append(temp)
                        

plt. clf()
fig = plt.figure(figsize=(12.0, 8.0)) #for full size graph download.eps', format='eps'
plt.xticks(size = 30)
plt.yticks(size = 30)
plt.xlabel('Base 2 Logarithm of Frequency (Hz)', fontsize=25,fontweight='bold')
plt.ylabel('Occurrence', fontsize=25,fontweight='bold')
plt.hist(hist,color = "#B7CEEC")
os.chdir('/home/student/Downloads')
plt.savefig('hist31.eps', format='eps')
plt.savefig('hist31.png')
a = hist
temp =[statistics.mean(a), statistics.median(a), statistics.mode(a), min(a), max(a),np.percentile(np.array(a), 25), np.percentile(np.array(a), 75)]
print(temp)
# Out:
# /home/student/.local/lib/python3.6/site-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/student/.local/lib/python3.6/site-packages/librosa/core/spectrum.py:1642: UserWarning: amplitude_to_db was called on complex input so phase information will be discarded. To suppress this warning, call amplitude_to_db(np.abs(S)) instead.
#   "amplitude_to_db was called on complex input so phase "
# [9.446254009165896, 8.981671692617073, 8.95064479699645, 8.012045341660594, 11.460505842476888, 8.886514459576734, 10.113583368122654]

# %%
os.chdir('/home/student/Downloads/new_violin_viola/romantic/viola/solo_train')
f_name = "/home/student/Downloads/new_violin_viola/romantic/viola/solo_train/12 Etudes for Viola No. 1: Allegro.mp3"
y, sr = librosa.load(f_name)
#mel = librosa.feature.melspectrogram(y=y,sr=sr)
X = librosa.stft(y)
S = librosa.amplitude_to_db(X, ref=np.max)
plt. clf()
fig = plt.figure(figsize=(12.0, 8.0)) #for full size graph download
librosa.display.specshow(S, y_axis='mel')
plt.colorbar(format='%+2.0f dB')
#plt.savefig(f'/home/student/Downloads/new_violin_viola/baroque/violin/solo/Hilary Hahn - J.S. Bach Partita for Violin Solo No. 1 in B Minor, BWV 1002 - 4. Doubl....mp3.png')
hop_length = 512
X = librosa.stft(y)
S = librosa.amplitude_to_db(X, ref=np.max)
        
l1 =[]
        #by default, there are 1025 frequency bins in 0 to sr/2 (sr = 22050)

        
hist=[]
hist1=[]
for i in range(len(S)):
    for j in range(len(S[0])):
        
        if S[i][j]>=(-11):
            temp = i *((22050/2)/1025)
            
            if temp >0:
                hist.append(math.log2(temp))
                hist1.append(temp)
                        

plt. clf()
fig = plt.figure(figsize=(12.0, 8.0)) #for full size graph download
plt.xticks(size = 30)
plt.yticks(size = 30)
plt.xlabel('Base 2 Logarithm of Frequency (Hz)', fontsize=25,fontweight='bold')
plt.ylabel('Occurrence', fontsize=25,fontweight='bold')
plt.hist(hist,color = "#B7CEEC")
os.chdir('/home/student/Downloads')
plt.savefig('hist33.eps', format='eps')
a = hist
temp =[statistics.mean(a), statistics.median(a), statistics.mode(a), min(a), max(a),np.percentile(np.array(a), 25), np.percentile(np.array(a), 75)]
print(temp)
# Out:
# /home/student/.local/lib/python3.6/site-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/student/.local/lib/python3.6/site-packages/librosa/core/spectrum.py:1642: UserWarning: amplitude_to_db was called on complex input so phase information will be discarded. To suppress this warning, call amplitude_to_db(np.abs(S)) instead.
#   "amplitude_to_db was called on complex input so phase "
# [8.792198249494067, 8.784634845557521, 8.784634845557521, 7.749010935826799, 11.551204152768625, 8.47147696029789, 8.819400263718197]

# %%
import numpy, scipy, matplotlib.pyplot as plt, IPython.display as ipd
import librosa, librosa.display
import numpy as np
import os
#os.chdir('/home/student/Downloads/new_violin_viola/romantic/viola/solo_train')
x, sr = librosa.load('/home/student/Downloads/new_violin_viola/romantic/viola/solo_train/12 Etudes for Viola No. 12: Andante.mp3')
y, sr = librosa.load('/home/student/Downloads/new_violin_viola/classical/violin/solo_train/Mozart Violin Concerto No. 5 Cadenza.mp3')
        #mel = librosa.feature.melspectrogram(y=y,sr=sr)
X = librosa.stft(y)
S = librosa.amplitude_to_db(X, ref=np.max)
plt. clf()
fig, ax = plt.subplots()
#fig = plt.figure(figsize=(15.0, 10.0)) #for full size graph download
#plt.title('Spectrogram of Mozart Violin Concerto No. 5 Cadenza', fontsize=20)
#plt.xlabel('Time', fontsize=18)
#plt.ylabel('Frequency', fontsize=18)
ax.set_title('Spectrogram of Mozart Violin Concerto No. 5 Cadenza')
img = librosa.display.specshow(librosa.amplitude_to_db(S,
                                                       ref=np.max),
                               y_axis='log', x_axis='time', ax=ax)
fig.colorbar(img, ax=ax, format="%+2.0f dB")
librosa.display.specshow(S, y_axis='mel')
#plt.colorbar(format='%+2.0f dB')
plt.savefig(f'/home/student/Downloads/temp.png')
# Out:
# /home/student/.local/lib/python3.6/site-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/student/.local/lib/python3.6/site-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/student/.local/lib/python3.6/site-packages/librosa/core/spectrum.py:1642: UserWarning: amplitude_to_db was called on complex input so phase information will be discarded. To suppress this warning, call amplitude_to_db(np.abs(S)) instead.
#   "amplitude_to_db was called on complex input so phase "

# %%
import math
os.chdir('/home/student/Downloads/new_violin_viola/baroque/violin/solo_test')
f_name = "/home/student/Downloads/new_violin_viola/baroque/violin/solo_test/Sonata No 1 in G Minor BWV 1001 IV Presto.mp3"
y, sr = librosa.load(f_name)
#mel = librosa.feature.melspectrogram(y=y,sr=sr)
X = librosa.stft(y)
S = librosa.amplitude_to_db(X, ref=np.max)
plt. clf()
fig = plt.figure(figsize=(12.0, 8.0)) #for full size graph download
librosa.display.specshow(S, y_axis='mel')
plt.colorbar(format='%+2.0f dB')
#plt.savefig(f'/home/student/Downloads/new_violin_viola/baroque/violin/solo/Hilary Hahn - J.S. Bach Partita for Violin Solo No. 1 in B Minor, BWV 1002 - 4. Doubl....mp3.png')
hop_length = 512
X = librosa.stft(y)
S = librosa.amplitude_to_db(X, ref=np.max)
        
l1 =[]
        #by default, there are 1025 frequency bins in 0 to sr/2 (sr = 22050)

        
hist=[]
hist1=[]
for i in range(len(S)):
    for j in range(len(S[0])):
        
        if S[i][j]>=(-11):
            temp = i *((22050/2)/1025)
            
            if temp >0:
                hist.append(math.log2(temp))
                hist1.append(temp)
                        

plt. clf()
fig = plt.figure(figsize=(12.0, 8.0)) #for full size graph download
plt.title('Histogram of Frequencies of Sonata No 1 in G Minor BWV 1001 IV Presto', fontsize=18)
plt.xlabel('Logarithmic Frequency(Hz)', fontsize=18)
plt.ylabel('Occurrence', fontsize=18)
plt.hist(hist)
plt.savefig('histtt')
# Out:
# /home/student/.local/lib/python3.6/site-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/student/.local/lib/python3.6/site-packages/librosa/core/spectrum.py:1642: UserWarning: amplitude_to_db was called on complex input so phase information will be discarded. To suppress this warning, call amplitude_to_db(np.abs(S)) instead.
#   "amplitude_to_db was called on complex input so phase "

# %%
import librosa
y, sr = librosa.load("(1s - 3m 44s) Sebastian Bohren - Violin Partita No. 3 in E Major, BWV 1006 I. Preludio.mp3")
S = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128,fmax=8000)
import matplotlib.pyplot as plt
plt.rc('xtick', labelsize=14) 
plt.rc('ytick', labelsize=14) 
fig, ax = plt.subplots()
S_dB = librosa.power_to_db(S, ref=np.max)
img = librosa.display.specshow(S_dB, x_axis='time',y_axis='mel', sr=sr,fmax=8000, ax=ax)
fig.colorbar(img, ax=ax, format='%+2.0f dB')
#ax.set(title='Mel-frequency spectrogram')
plt.savefig('mel1', format='png')
# Out:
# /home/student/.local/lib/python3.6/site-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")

# %%
plt.clf()
y, sr = librosa.load("(5s - 3m 37s) Bach Partita 3; Prelude played on viola by Scott Slapin.mp3")
S = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128,fmax=8000)
import matplotlib.pyplot as plt
plt.rc('xtick', labelsize=14) 
plt.rc('ytick', labelsize=14) 
fig, ax = plt.subplots()
S_dB = librosa.power_to_db(S, ref=np.max)
img = librosa.display.specshow(S_dB, x_axis='time',y_axis='mel', sr=sr,fmax=8000, ax=ax)

fig.colorbar(img, ax=ax, format='%+2.0f dB')
#ax.set(title='Mel-frequency spectrogram')
plt.savefig('mel2', format='eps')
# Out:
# /home/student/.local/lib/python3.6/site-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")

# %%
import math
os.chdir('/home/student/Downloads')
f_name = "(1s - 3m 44s) Sebastian Bohren - Violin Partita No. 3 in E Major, BWV 1006 I. Preludio.mp3"
y, sr = librosa.load(f_name)
#mel = librosa.feature.melspectrogram(y=y,sr=sr)
X = librosa.stft(y)
S = librosa.amplitude_to_db(X, ref=np.max)
plt. clf()
fig = plt.figure(figsize=(12.0, 8.0)) #for full size graph download
librosa.display.specshow(S, y_axis='mel')
plt.colorbar(format='%+2.0f dB')
#plt.savefig(f'/home/student/Downloads/new_violin_viola/baroque/violin/solo/Hilary Hahn - J.S. Bach Partita for Violin Solo No. 1 in B Minor, BWV 1002 - 4. Doubl....mp3.png')
hop_length = 512
X = librosa.stft(y)
S = librosa.amplitude_to_db(X, ref=np.max)
        
l1 =[]
        #by default, there are 1025 frequency bins in 0 to sr/2 (sr = 22050)

        
hist=[]
hist1=[]
for i in range(len(S)):
    for j in range(len(S[0])):
        
        if S[i][j]>=(-13):
            temp = i *((22050/2)/1025)
            
            if temp >0:
                hist.append(math.log2(temp))
                hist1.append(temp)
                        

plt. clf()
fig = plt.figure(figsize=(12.0, 8.0)) #for full size graph download
#plt.title('Histogram of Frequencies of Violin Partita No. 3 in E Major', fontsize=18)
plt.xticks(size = 30)
plt.yticks(size = 30)
plt.xlabel('Base 2 Logarithm of Frequency (Hz)', fontsize=25,fontweight='bold')
plt.ylabel('Occurrence', fontsize=25,fontweight='bold')
plt.hist(hist, color='orange')
plt.savefig('histe1', format='eps')
# Out:
# /home/student/.local/lib/python3.6/site-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/student/.local/lib/python3.6/site-packages/librosa/core/spectrum.py:1642: UserWarning: amplitude_to_db was called on complex input so phase information will be discarded. To suppress this warning, call amplitude_to_db(np.abs(S)) instead.
#   "amplitude_to_db was called on complex input so phase "

# %%
import math
os.chdir('/home/student/Downloads/')
f_name = "(5s - 3m 37s) Bach Partita 3; Prelude played on viola by Scott Slapin.mp3"
y, sr = librosa.load(f_name)
#mel = librosa.feature.melspectrogram(y=y,sr=sr)
X = librosa.stft(y)
S = librosa.amplitude_to_db(X, ref=np.max)
plt. clf()
fig = plt.figure(figsize=(12.0, 8.0)) #for full size graph download
librosa.display.specshow(S, y_axis='mel')
plt.colorbar(format='%+2.0f dB')
#plt.savefig(f'/home/student/Downloads/new_violin_viola/baroque/violin/solo/Hilary Hahn - J.S. Bach Partita for Violin Solo No. 1 in B Minor, BWV 1002 - 4. Doubl....mp3.png')
hop_length = 512
X = librosa.stft(y)
S = librosa.amplitude_to_db(X, ref=np.max)
        
l1 =[]
        #by default, there are 1025 frequency bins in 0 to sr/2 (sr = 22050)

        
hist=[]
hist1=[]
for i in range(len(S)):
    for j in range(len(S[0])):
        
        if S[i][j]>=(-8):
            temp = i *((22050/2)/1025)
            
            if temp >0:
                hist.append(math.log2(temp))
                hist1.append(temp)
                        

plt. clf()
fig = plt.figure(figsize=(12.0, 8.0)) #for full size graph download
#plt.title('Histogram of Frequencies of Sonata No 1 in G Minor BWV 1001 IV Presto', fontsize=18)
plt.xticks(size = 30)
plt.yticks(size = 30)
plt.xlabel('Base 2 Logarithm of Frequency (Hz)', fontsize=25,fontweight='bold')
plt.ylabel('Occurrence', fontsize=25,fontweight='bold')
plt.hist(hist, color='orange')
plt.savefig('histe2.eps', format='eps')
# Out:
# /home/student/.local/lib/python3.6/site-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/student/.local/lib/python3.6/site-packages/librosa/core/spectrum.py:1642: UserWarning: amplitude_to_db was called on complex input so phase information will be discarded. To suppress this warning, call amplitude_to_db(np.abs(S)) instead.
#   "amplitude_to_db was called on complex input so phase "

# %%
plt.clf()
y, sr = librosa.load("(5s - 3m 37s) Bach Partita 3; Prelude played on viola by Scott Slapin.mp3")
S = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128,fmax=8000)
import matplotlib.pyplot as plt
plt.rc('xtick', labelsize=14) 
plt.rc('ytick', labelsize=14) 
fig, ax = plt.subplots()
S_dB = librosa.power_to_db(S, ref=np.max)
img = librosa.display.specshow(S_dB, x_axis='time',y_axis='mel', sr=sr,fmax=8000, ax=ax)

fig.colorbar(img, ax=ax, format='%+2.0f dB')
#ax.set(title='Mel-frequency spectrogram')
plt.savefig('mel2', format='eps')
# Out:
# /home/student/.local/lib/python3.6/site-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")

# %%
import librosa
y, sr = librosa.load("(5s - 3m 37s) Bach Partita 3; Prelude played on viola by Scott Slapin.mp3")
S = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128,fmax=8000)
import matplotlib.pyplot as plt
plt.rc('xtick', labelsize=14) 
plt.rc('ytick', labelsize=14) 
fig, ax = plt.subplots()
S_dB = librosa.power_to_db(S, ref=np.max)
img = librosa.display.specshow(S_dB, x_axis='time',y_axis='mel', sr=sr,fmax=8000, ax=ax)
fig.colorbar(img, ax=ax, format='%+2.00f dB')
#ax.set(title='Mel-frequency spectrogram')
plt.savefig('mel2', format='png')
# Out:
# /home/student/.local/lib/python3.6/site-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")

# %% [markdown]
# Non-solo

# %%
#os.chdir('/home/student/Downloads/new_violin_viola/classical/violin/solo_test')
f_name = "/home/student/Downloads/violin_viola/baroque/violin/non_solo_test/Sonata in A, BWV 1015-Dolce_PROCESSED.wav"
y, sr = librosa.load(f_name)
#mel = librosa.feature.melspectrogram(y=y,sr=sr)
X = librosa.stft(y)
S = librosa.amplitude_to_db(X, ref=np.max)
plt. clf()
fig = plt.figure(figsize=(12.0, 8.0)) #for full size graph download
librosa.display.specshow(S, y_axis='mel')
plt.colorbar(format='%+2.0f dB')
#plt.savefig(f'/home/student/Downloads/new_violin_viola/baroque/violin/solo/Hilary Hahn - J.S. Bach Partita for Violin Solo No. 1 in B Minor, BWV 1002 - 4. Doubl....mp3.png')
hop_length = 512
X = librosa.stft(y)
S = librosa.amplitude_to_db(X, ref=np.max)
        
l1 =[]
        #by default, there are 1025 frequency bins in 0 to sr/2 (sr = 22050)

        
hist=[]
hist1=[]
for i in range(len(S)):
    for j in range(len(S[0])):
        
        if S[i][j]>=(-11):
            temp = i *((22050/2)/1025)
            
            if temp >0:
                hist.append(math.log2(temp))
                hist1.append(temp)
                        

plt. clf()
fig = plt.figure(figsize=(12.0, 8.0)) #for full size graph download
plt.xticks(size = 30)
plt.yticks(size = 30)
plt.xlabel('Base 2 Logarithm of Frequency (Hz)', fontsize=25,fontweight='bold')
plt.ylabel('Occurrence', fontsize=25,fontweight='bold')
plt.hist(hist,color = "#3D366D")
os.chdir('/home/student/Downloads')
plt.savefig('nhist11.eps', format='eps')
a = hist
temp =[statistics.mean(a), statistics.median(a), statistics.mode(a), min(a), max(a),np.percentile(np.array(a), 25), np.percentile(np.array(a), 75)]
print(temp)
# Out:
# [9.064745808874447, 9.127522559080528, 9.127522559080528, 8.070939030714161, 11.309725890301278, 8.381279151326313, 9.556365857884403]

# %%
#os.chdir('/home/student/Downloads/new_violin_viola/classical/violin/solo_test')
f_name = "/home/student/Downloads/violin_viola/baroque/viola/non_solo_test/Vivaldi Sonata No.5 in E Minor, Allegro, for Viola and Piano_PROCESSED.wav"
y, sr = librosa.load(f_name)
#mel = librosa.feature.melspectrogram(y=y,sr=sr)
X = librosa.stft(y)
S = librosa.amplitude_to_db(X, ref=np.max)
plt. clf()
fig = plt.figure(figsize=(12.0, 8.0)) #for full size graph download
librosa.display.specshow(S, y_axis='mel')
plt.colorbar(format='%+2.0f dB')
#plt.savefig(f'/home/student/Downloads/new_violin_viola/baroque/violin/solo/Hilary Hahn - J.S. Bach Partita for Violin Solo No. 1 in B Minor, BWV 1002 - 4. Doubl....mp3.png')
hop_length = 512
X = librosa.stft(y)
S = librosa.amplitude_to_db(X, ref=np.max)
        
l1 =[]
        #by default, there are 1025 frequency bins in 0 to sr/2 (sr = 22050)

        
hist=[]
hist1=[]
for i in range(len(S)):
    for j in range(len(S[0])):
        
        if S[i][j]>=(-11):
            temp = i *((22050/2)/1025)
            
            if temp >0:
                hist.append(math.log2(temp))
                hist1.append(temp)
                        

plt. clf()
fig = plt.figure(figsize=(12.0, 8.0)) #for full size graph download
plt.xticks(size = 30)
plt.yticks(size = 30)
plt.xlabel('Base 2 Logarithm of Frequency (Hz)', fontsize=25,fontweight='bold')
plt.ylabel('Occurrence', fontsize=25,fontweight='bold')
plt.hist(hist,color = "#3D366D")
os.chdir('/home/student/Downloads')
plt.savefig('nhist12.eps', format='eps')
a = hist
temp =[statistics.mean(a), statistics.median(a), statistics.mode(a), min(a), max(a),np.percentile(np.array(a), 25), np.percentile(np.array(a), 75)]
print(temp)
# Out:
# [8.708785992263572, 8.59700784238175, 8.514545682189777, 7.886514459576734, 9.784634845557521, 8.514545682189777, 8.95064479699645]

# %%
#os.chdir('/home/student/Downloads/new_violin_viola/classical/violin/solo_test')
f_name = "/home/student/Downloads/violin_viola/classical/violin/non_solo_train/Violin Sonata in A Major, D 574 II Scherzo Presto_PROCESSED.wav"
y, sr = librosa.load(f_name)
#mel = librosa.feature.melspectrogram(y=y,sr=sr)
X = librosa.stft(y)
S = librosa.amplitude_to_db(X, ref=np.max)
plt. clf()
fig = plt.figure(figsize=(12.0, 8.0)) #for full size graph download
librosa.display.specshow(S, y_axis='mel')
plt.colorbar(format='%+2.0f dB')
#plt.savefig(f'/home/student/Downloads/new_violin_viola/baroque/violin/solo/Violin Sonata No 2 in A Op 12 No 2 III Allegro piacevole_PROCESSED.wav')
hop_length = 512
X = librosa.stft(y)
S = librosa.amplitude_to_db(X, ref=np.max)
        
l1 =[]
        #by default, there are 1025 frequency bins in 0 to sr/2 (sr = 22050)

        
hist=[]
hist1=[]
for i in range(len(S)):
    for j in range(len(S[0])):
        
        if S[i][j]>=(-11):
            temp = i *((22050/2)/1025)
            
            if temp >0:
                hist.append(math.log2(temp))
                hist1.append(temp)
                        

plt. clf()
fig = plt.figure(figsize=(12.0, 8.0)) #for full size graph download
plt.xticks(size = 30)
plt.yticks(size = 30)
plt.xlabel('Base 2 Logarithm of Frequency (Hz)', fontsize=25,fontweight='bold')
plt.ylabel('Occurrence', fontsize=25,fontweight='bold')
plt.hist(hist,color = "#FFBF00")
os.chdir('/home/student/Downloads')
plt.savefig('nhist21.eps', format='eps')
a = hist
temp =[statistics.mean(a), statistics.median(a), statistics.mode(a), min(a), max(a),np.percentile(np.array(a), 25), np.percentile(np.array(a), 75)]
print(temp)
# Out:
# [10.157496249675836, 10.775810995170515, 8.234437762997041, 8.070939030714161, 11.415767527711603, 8.95064479699645, 11.13444197302032]

# %%
#os.chdir('/home/student/Downloads/new_violin_viola/classical/violin/solo_test')
f_name = "/home/student/Downloads/violin_viola/classical/viola/non_solo_test/Andante _ Allegretto in C major KV 404(Mozart)_PROCESSED.wav"
y, sr = librosa.load(f_name)
#mel = librosa.feature.melspectrogram(y=y,sr=sr)
X = librosa.stft(y)
S = librosa.amplitude_to_db(X, ref=np.max)
plt. clf()
fig = plt.figure(figsize=(12.0, 8.0)) #for full size graph download
librosa.display.specshow(S, y_axis='mel')
plt.colorbar(format='%+2.0f dB')
#plt.savefig(f'/home/student/Downloads/new_violin_viola/baroque/violin/solo/Violin Sonata No 2 in A Op 12 No 2 III Allegro piacevole_PROCESSED.wav')
hop_length = 512
X = librosa.stft(y)
S = librosa.amplitude_to_db(X, ref=np.max)
        
l1 =[]
        #by default, there are 1025 frequency bins in 0 to sr/2 (sr = 22050)

        
hist=[]
hist1=[]
for i in range(len(S)):
    for j in range(len(S[0])):
        
        if S[i][j]>=(-11):
            temp = i *((22050/2)/1025)
            
            if temp >0:
                hist.append(math.log2(temp))
                hist1.append(temp)
                        

plt. clf()
fig = plt.figure(figsize=(12.0, 8.0)) #for full size graph download
plt.xticks(size = 30)
plt.yticks(size = 30)
plt.xlabel('Base 2 Logarithm of Frequency (Hz)', fontsize=25,fontweight='bold')
plt.ylabel('Occurrence', fontsize=25,fontweight='bold')
plt.hist(hist,color = "#FFBF00")
os.chdir('/home/student/Downloads')
plt.savefig('nhist22.eps', format='eps')
a = hist
temp =[statistics.mean(a), statistics.median(a), statistics.mode(a), min(a), max(a),np.percentile(np.array(a), 25), np.percentile(np.array(a), 75)]
print(temp)
# Out:
# [9.778348392801972, 9.966241652047469, 10.041792685054645, 8.181970343102906, 10.482365276440627, 9.535607297717606, 10.041792685054645]

# %%
#os.chdir('/home/student/Downloads/new_violin_viola/classical/violin/solo_test')
f_name = "/home/student/Downloads/violin_viola/romantic/violin/non_solo_train/Violin Sonata No 1 in A minor Op 105  I Mit leidenschaftlichem_PROCESSED.wav"
y, sr = librosa.load(f_name)
#mel = librosa.feature.melspectrogram(y=y,sr=sr)
X = librosa.stft(y)
S = librosa.amplitude_to_db(X, ref=np.max)
plt. clf()
fig = plt.figure(figsize=(12.0, 8.0)) #for full size graph download
librosa.display.specshow(S, y_axis='mel')
plt.colorbar(format='%+2.0f dB')
#plt.savefig(f'/home/student/Downloads/new_violin_viola/baroque/violin/solo/Violin Sonata No 2 in A Op 12 No 2 III Allegro piacevole_PROCESSED.wav')
hop_length = 512
X = librosa.stft(y)
S = librosa.amplitude_to_db(X, ref=np.max)
        
l1 =[]
        #by default, there are 1025 frequency bins in 0 to sr/2 (sr = 22050)

        
hist=[]
hist1=[]
for i in range(len(S)):
    for j in range(len(S[0])):
        
        if S[i][j]>=(-11):
            temp = i *((22050/2)/1025)
            
            if temp >0:
                hist.append(math.log2(temp))
                hist1.append(temp)
                        

plt. clf()
fig = plt.figure(figsize=(12.0, 8.0)) #for full size graph download
plt.xticks(size = 30)
plt.yticks(size = 30)
plt.xlabel('Base 2 Logarithm of Frequency (Hz)', fontsize=25,fontweight='bold')
plt.ylabel('Occurrence', fontsize=25,fontweight='bold')
plt.hist(hist,color = "#F08080")
os.chdir('/home/student/Downloads')
plt.savefig('nhist31.eps', format='eps')
a = hist
temp =[statistics.mean(a), statistics.median(a), statistics.mode(a), min(a), max(a),np.percentile(np.array(a), 25), np.percentile(np.array(a), 75)]
print(temp)
# Out:
# [8.848150971886735, 9.012045341660594, 9.041792685054645, 7.95064479699645, 10.966241652047469, 8.675010354383023, 9.041792685054645]

# %%
#os.chdir('/home/student/Downloads/new_violin_viola/classical/violin/solo_test')
f_name = "/home/student/Downloads/violin_viola/romantic/viola/non_solo_train/viola sonata op 120 no 1 in F minor Allegro_PROCESSED.wav"
y, sr = librosa.load(f_name)
#mel = librosa.feature.melspectrogram(y=y,sr=sr)
X = librosa.stft(y)
S = librosa.amplitude_to_db(X, ref=np.max)
plt. clf()
fig = plt.figure(figsize=(12.0, 8.0)) #for full size graph download
librosa.display.specshow(S, y_axis='mel')
plt.colorbar(format='%+2.0f dB')
#plt.savefig(f'/home/student/Downloads/new_violin_viola/baroque/violin/solo/Violin Sonata No 2 in A Op 12 No 2 III Allegro piacevole_PROCESSED.wav')
hop_length = 512
X = librosa.stft(y)
S = librosa.amplitude_to_db(X, ref=np.max)
        
l1 =[]
        #by default, there are 1025 frequency bins in 0 to sr/2 (sr = 22050)

        
hist=[]
hist1=[]
for i in range(len(S)):
    for j in range(len(S[0])):
        
        if S[i][j]>=(-11):
            temp = i *((22050/2)/1025)
            
            if temp >0:
                hist.append(math.log2(temp))
                hist1.append(temp)
                        

plt. clf()
fig = plt.figure(figsize=(12.0, 8.0)) #for full size graph download
plt.xticks(size = 30)
plt.yticks(size = 30)
plt.xlabel('Base 2 Logarithm of Frequency (Hz)', fontsize=25,fontweight='bold')
plt.ylabel('Occurrence', fontsize=25,fontweight='bold')
plt.hist(hist,color = "#F08080")
os.chdir('/home/student/Downloads')
plt.savefig('nhist32.eps', format='eps')
a = hist
temp =[statistics.mean(a), statistics.median(a), statistics.mode(a), min(a), max(a),np.percentile(np.array(a), 25), np.percentile(np.array(a), 75)]
print(temp)
# Out:
# [8.916110252734734, 8.853347595641536, 8.853347595641536, 7.886514459576734, 11.221498707289543, 8.675010354383023, 9.041792685054645]
